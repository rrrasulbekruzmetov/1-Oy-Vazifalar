# %% [markdown]
# # Pandas kutubxonasini o`rnatib  olamiz

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 1.9 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/11.5 MB 3.5 MB/s eta 0:00:03
#    ------ --------------------------------- 1.8/11.5 MB 3.3 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/11.5 MB 3.0 MB/s eta 0:00:04
#    ------------- -------------------------- 3.9/11.5 MB 3.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.0/11.5 MB 3.9 MB/s eta 0:00:02
#    --------------------- ------------------ 6.0/11.5 MB 4.1 MB/s eta 0:00:02
#    ------------------------- -------------- 7.3/11.5 MB 4.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.5 MB 4.5 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.5 MB 4.6 MB/s eta 0:00:01
# ...

# %% [markdown]
# # Pandas kutubxonasini import qilib olish

# %%
import pandas as pd

# %% [markdown]
# # Datani o`ng tamonga olish

# %%
df = pd.read_csv('museum_visitors.csv')

# %% [markdown]
# # Data dan dastlabki 5 ta qatorni chiqarish

# %%
df.head()
# Out:
#          Date  Avila Adobe  Firehouse Museum  Chinese American Museum  \
# 0  2014-01-01        24778              4486                     1581
# 1  2014-02-01        18976              4172                     1785
# 2  2014-03-01        25231              7082                     3229
# 3  2014-04-01        26989              6756                     2129
# 4  2014-05-01        36883             10858                     3676
#
#    America Tropical Interpretive Center
# 0                                  6602
# 1                                  5029
# 2                                  8129
# 3                                  2824
# 4                                 10694

# %% [markdown]
# # Data dan dastlabki 10 ta qatorni chiqarish

# %%
df.head(10)
# Out:
#          Date  Avila Adobe  Firehouse Museum  Chinese American Museum  \
# 0  2014-01-01        24778              4486                     1581
# 1  2014-02-01        18976              4172                     1785
# 2  2014-03-01        25231              7082                     3229
# 3  2014-04-01        26989              6756                     2129
# 4  2014-05-01        36883             10858                     3676
# 5  2014-06-01        29487              5751                     2121
# 6  2014-07-01        32378              5406                     2239
# 7  2014-08-01        37680              8619                     1769
# 8  2014-09-01        28473             61192                     1073
# 9  2014-10-01        27995              6488                     1979
#
#    America Tropical Interpretive Center
# 0                                  6602
# 1                                  5029
# 2                                  8129
# ...

# %% [markdown]
# # Data dan  eng oxiridan 5 ta qatorni chiqarish

# %%
df.tail()
# Out:
#           Date  Avila Adobe  Firehouse Museum  Chinese American Museum  \
# 54  2018-07-01        23136              4191                     2620
# 55  2018-08-01        20815              4866                     2409
# 56  2018-09-01        21020              4956                     2146
# 57  2018-10-01        19280              4622                     2364
# 58  2018-11-01        17163              4082                     2385
#
#     America Tropical Interpretive Center
# 54                                  4718
# 55                                  3891
# 56                                  3180
# 57                                  3775
# 58                                  4562

# %% [markdown]
# # Data dan  eng oxiridan 10 ta qatorni chiqarish

# %%
df.tail(10)
# Out:
#           Date  Avila Adobe  Firehouse Museum  Chinese American Museum  \
# 49  2018-02-01        14718              3306                     2710
# 50  2018-03-01        19001              5225                     4529
# 51  2018-04-01        18966              4535                     2750
# 52  2018-05-01        25173              8013                     4960
# 53  2018-06-01        22171              4635                     2518
# 54  2018-07-01        23136              4191                     2620
# 55  2018-08-01        20815              4866                     2409
# 56  2018-09-01        21020              4956                     2146
# 57  2018-10-01        19280              4622                     2364
# 58  2018-11-01        17163              4082                     2385
#
#     America Tropical Interpretive Center
# 49                                  5705
# 50                                  4909
# 51                                  4650
# ...

# %% [markdown]
# # Featurelarni alohida alohida ko`rish

# %%
df['Date']
# Out:
# 0     2014-01-01
# 1     2014-02-01
# 2     2014-03-01
# 3     2014-04-01
# 4     2014-05-01
# 5     2014-06-01
# 6     2014-07-01
# 7     2014-08-01
# 8     2014-09-01
# 9     2014-10-01
# 10    2014-11-01
# 11    2014-12-01
# 12    2015-01-01
# 13    2015-02-01
# 14    2015-03-01
# 15    2015-04-01
# 16    2015-05-01
# 17    2015-06-01
# 18    2015-07-01
# 19    2015-08-01
# 20    2015-09-01
# 21    2015-10-01
# 22    2015-11-01
# 23    2015-12-01
# 24    2016-01-01
# 25    2016-02-01
# 26    2016-03-01
# 27    2016-04-01
# 28    2016-05-01
# 29    2016-06-01
# 30    2016-07-01
# 31    2016-08-01
# 32    2016-09-01
# 33    2016-10-01
# 34    2016-11-01
# 35    2016-12-01
# 36    2017-01-01
# 37    2017-02-01
# 38    2017-03-01
# 39    2017-04-01
# 40    2017-05-01
# 41    2017-06-01
# 42    2017-07-01
# 43    2017-08-01
# 44    2017-09-01
# 45    2017-10-01
# 46    2017-11-01
# 47    2017-12-01
# 48    2018-01-01
# 49    2018-02-01
# 50    2018-03-01
# 51    2018-04-01
# ...

# %%
df['Chinese American Museum']
# Out:
# 0     1581
# 1     1785
# 2     3229
# 3     2129
# 4     3676
# 5     2121
# 6     2239
# 7     1769
# 8     1073
# 9     1979
# 10    2404
# 11    1319
# 12    1823
# 13    1558
# 14    2336
# 15    3057
# 16    4009
# 17    2544
# 18    3057
# 19    2415
# 20    1398
# 21    2237
# 22    2850
# 23    2075
# 24    2150
# 25    2547
# 26    7702
# 27    3485
# 28    4565
# 29    3034
# 30    2776
# 31    2153
# 32    1754
# 33    2607
# 34    2248
# 35    2263
# 36    2531
# 37    2139
# 38    5966
# 39    3273
# 40    5585
# 41    2946
# 42    2939
# 43    1784
# 44    1704
# 45    2419
# 46    2685
# 47    2768
# 48    2477
# 49    2710
# 50    4529
# 51    2750
# 52    4960
# 53    2518
# 54    2620
# 55    2409
# 56    2146
# 57    2364
# 58    2385
# Name: Chinese American Museum, dtype: int64

# %% [markdown]
# # Har bir feature dagi classlar sonini topish

# %%
df['Avila Adobe'].value_counts()
# Out:
# Avila Adobe
# 24778    1
# 18976    1
# 25231    1
# 26989    1
# 36883    1
# 29487    1
# 32378    1
# 37680    1
# 28473    1
# 27995    1
# 25691    1
# 18754    1
# 20438    1
# 15578    1
# 21297    1
# 26670    1
# 34383    1
# 30569    1
# 41242    1
# 30700    1
# 20967    1
# 29764    1
# 24483    1
# 21426    1
# 19659    1
# 17378    1
# 20322    1
# 24521    1
# 31728    1
# 23696    1
# 31689    1
# 25987    1
# 22897    1
# 25040    1
# 17760    1
# 20107    1
# 18792    1
# 14035    1
# 20680    1
# 25234    1
# 30029    1
# 22169    1
# 30831    1
# 27009    1
# 23403    1
# 22164    1
# 17629    1
# 18339    1
# 16265    1
# 14718    1
# 19001    1
# 18966    1
# 25173    1
# 22171    1
# 23136    1
# 20815    1
# 21020    1
# 19280    1
# 17163    1
# Name: count, dtype: int64

# %%
df['America Tropical Interpretive Center'].value_counts()
# Out:
# America Tropical Interpretive Center
# 6602     1
# 5029     1
# 8129     1
# 2824     1
# 10694    1
# 11036    1
# 13490    1
# 9139     1
# 5661     1
# 7356     1
# 9773     1
# 7184     1
# 6250     1
# 5907     1
# 9884     1
# 7254     1
# 13207    1
# 11102    1
# 11072    1
# 12096    1
# 6608     1
# 12524    1
# 6677     1
# 5967     1
# 6587     1
# 6955     1
# 9979     1
# 5113     1
# 7757     1
# 6751     1
# 12188    1
# 6245     1
# 6977     1
# 6282     1
# 6365     1
# 5223     1
# 4929     1
# 4493     1
# 6271     1
# 6685     1
# 7556     1
# 6818     1
# 8675     1
# 6212     1
# 4607     1
# 6097     1
# 6757     1
# 6780     1
# 5837     1
# 5705     1
# 4909     1
# 4650     1
# 5626     1
# 4694     1
# 4718     1
# 3891     1
# 3180     1
# 3775     1
# 4562     1
# Name: count, dtype: int64

# %% [markdown]
# # Keraksisz Ustunlarni tashlab yuborish

# %% [markdown]
# # axis = 1 USTUN // axis = 0 QATOR

# %%
df.drop('Firehouse Museum', axis=1)
# Out:
#           Date  Avila Adobe  Chinese American Museum  \
# 0   2014-01-01        24778                     1581
# 1   2014-02-01        18976                     1785
# 2   2014-03-01        25231                     3229
# 3   2014-04-01        26989                     2129
# 4   2014-05-01        36883                     3676
# 5   2014-06-01        29487                     2121
# 6   2014-07-01        32378                     2239
# 7   2014-08-01        37680                     1769
# 8   2014-09-01        28473                     1073
# 9   2014-10-01        27995                     1979
# 10  2014-11-01        25691                     2404
# 11  2014-12-01        18754                     1319
# 12  2015-01-01        20438                     1823
# 13  2015-02-01        15578                     1558
# 14  2015-03-01        21297                     2336
# 15  2015-04-01        26670                     3057
# 16  2015-05-01        34383                     4009
# ...

# %% [markdown]
# # Drop qilingan ustunni dataning o`zidan ham o`chirish

# %%
df.drop('Avila Adobe', axis=1, inplace=True)

# %%
df
# Out:
#     Firehouse Museum  Chinese American Museum  \
# 0               4486                     1581
# 1               4172                     1785
# 2               7082                     3229
# 3               6756                     2129
# 4              10858                     3676
# 5               5751                     2121
# 6               5406                     2239
# 7               8619                     1769
# 8              61192                     1073
# 9               6488                     1979
# 10              4189                     2404
# 11              4339                     1319
# 12              3858                     1823
# 13              3742                     1558
# 14              5390                     2336
# 15              7000                     3057
# 16             12528                     4009
# 17              5377                     2544
# 18              6111                     3057
# ...
